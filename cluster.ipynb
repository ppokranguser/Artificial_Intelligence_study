# %% [markdown]
# <a href="https://colab.research.google.com/github/ppokranguser/Artificial_Intelligence_study/blob/main/cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.DataFrame(columns=['x', 'y'])

# %%
df.loc[0] = [3,1]
df.loc[1] = [4,1]
df.loc[2] = [3,2]
df.loc[3] = [4,2]
df.loc[4] = [10,5]
df.loc[5] = [10,6]
df.loc[6] = [11,5]
df.loc[7] = [11,6]
df.loc[8] = [15,1]
df.loc[9] = [15,2]
df.loc[10] = [16,1]
df.loc[11] = [16,2]

# %%
df.head(20)
# Out:
#      x  y
# 0    3  1
# 1    4  1
# 2    3  2
# 3    4  2
# 4   10  5
# 5   10  6
# 6   11  5
# 7   11  6
# 8   15  1
# 9   15  2
# 10  16  1
# 11  16  2

# %%
# visualize data point
sns.lmplot(x='x', y='y', data=df, fit_reg=False, scatter_kws={"s":200}) # x-axis, y-axis, data, no line, marker size

# title
plt.title('kmean plot')

# x-axis label
plt.xlabel('x')

# y-axis label
plt.ylabel('y')
# Out:
# Text(42.12500000000001, 0.5, 'y')

# %%
# convert dataframe to numpy array
data_points = df.values

# %%
kmeans = KMeans(n_clusters=3).fit(data_points)

# %%
# cluster id for each data point
kmeans.labels_
# Out:
# array([0, 0, 0, 0, 2, 2, 2, 2, 1, 1, 1, 1], dtype=int32)

# %%
# this is final centroids position
kmeans.cluster_centers_
# Out:
# array([[ 3.5,  1.5],
#        [15.5,  1.5],
#        [10.5,  5.5]])

# %%
df['cluster_id'] = kmeans.labels_

# %%
df.head(12)
# Out:
#      x  y  cluster_id
# 0    3  1           0
# 1    4  1           0
# 2    3  2           0
# 3    4  2           0
# 4   10  5           2
# 5   10  6           2
# 6   11  5           2
# 7   11  6           2
# 8   15  1           1
# 9   15  2           1
# 10  16  1           1
# 11  16  2           1

# %%
sns.lmplot(x='x', y='y', data=df, fit_reg=False, # x-axis, y-axis, data, no line
           scatter_kws={"s":150}, # marker size
           hue="cluster_id") # color

# title
plt.title('after kmean clustering')
# Out:
# Text(0.5, 1.0, 'after kmean clustering')
